# %%
import pandas as pd
import numpy as np 
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("apple_quality.csv")
df=df.dropna()

# %%
col=['A_id','Size','Weight','Sweetness','Crunchiness','Ripeness','Acidity','Quality']
table=df[col]
print(table)
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006 -1.303849
# ...      ...       ...       ...        ...          ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# 3      0.790723217    good
# ...

# %%
tablex=pd.get_dummies(table,columns=['Quality'],dtype='int')
tablex
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006 -1.303849
# ...      ...       ...       ...        ...          ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075 -0.776571
#
#            Acidity  Quality_bad  Quality_good
# 0     -0.491590483            0             1
# 1     -0.722809367            0             1
# ...

# %%
X=table.drop(columns=['Quality','A_id'])
Y=table['Quality']

# %%
pd.crosstab(df['Ripeness'],df['Quality']).plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size = 0.15)
print(f"X_train : {x_train.shape}\nY_train : {y_train.shape}\nX_test : {x_test.shape}\nY_test : {y_test.shape}")
# Out:
# X_train : (3400, 6)
# Y_train : (3400,)
# X_test : (600, 6)
# Y_test : (600,)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train.values,y_train.values)
# Out:
# LogisticRegression()

# %%
model.score(x_train.values,y_train.values)
model.score(x_test.values,y_test.values)
# Out:
# 0.7066666666666667
